# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Q16 : Import datasets from the Data folder from CSV.

# %%
df_c = pd.read_csv (r'D:\jupyter\python_competition\questions\customer.csv')
df_i = pd.read_csv (r'D:\jupyter\python_competition\questions\iris.csv')
df_p = pd.read_csv (r'D:\jupyter\python_competition\questions\products.csv')
df_r = pd.read_csv (r'D:\jupyter\python_competition\questions\rectangles_old.csv')
df_s = pd.read_csv (r'D:\jupyter\python_competition\questions\sales.csv')

# %%
df_p
# Out:
#    p_id       product  price
# 0     1     Hard Disk     80
# 1     2           RAM     90
# 2     3       Monitor     75
# 3     4           CPU     55
# 4     5      Keyboard     20
# 5     6         Mouse     10
# 6     7   Motherboard     50
# 7     8  Power supply     20

# %%
df_s
# Out:
#    sale_id  c_id  p_id  product  qty store
# 0        1     2     3  Monitor    2   ABC
# 1        2     2     4      CPU    1   DEF
# 2        3     1     3  Monitor    3   ABC
# 3        4     4     2      RAM    2   DEF
# 4        5     2     3  Monitor    3   ABC
# 5        6     3     3  Monitor    2   DEF
# 6        7     2     2      RAM    3   ABC
# 7        8     3     2      RAM    2   DEF
# 8        9     2     3  Monitor    2   ABC

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q17: How many unique products are sold?

# %%
# Q17: How many unique products are sold?

print("The number of unique products sold are :-")
df_s['product'].nunique()
# Out:
# The number of unique products sold are :-
# 3

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q18: List the unique products sold.

# %%
print(df_s['product'].unique())
# Out:
# ['Monitor' 'CPU' 'RAM']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q19: List the quantity sold for each product and product id (No Multilevel indexing).

# %%
df_s.groupby(['product','p_id'], as_index=False).agg({'qty':'sum'})
# Out:
#    product  p_id  qty
# 0      CPU     4    1
# 1  Monitor     3   12
# 2      RAM     2    7

# %%
df_p
# Out:
#    p_id       product  price
# 0     1     Hard Disk     80
# 1     2           RAM     90
# 2     3       Monitor     75
# 3     4           CPU     55
# 4     5      Keyboard     20
# 5     6         Mouse     10
# 6     7   Motherboard     50
# 7     8  Power supply     20

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q20: For each product, give the total Quantity sold and the revenue earned from the total sales (price x quantity).

# %%
df_merge = pd.merge(df_p, df_s)

df_merge
# Out:
#    p_id  product  price  sale_id  c_id  qty store
# 0     2      RAM     90        4     4    2   DEF
# 1     2      RAM     90        7     2    3   ABC
# 2     2      RAM     90        8     3    2   DEF
# 3     3  Monitor     75        1     2    2   ABC
# 4     3  Monitor     75        3     1    3   ABC
# 5     3  Monitor     75        5     2    3   ABC
# 6     3  Monitor     75        6     3    2   DEF
# 7     3  Monitor     75        9     2    2   ABC
# 8     4      CPU     55        2     2    1   DEF

# %%
df_merge['total'] = df_merge['price'] * df_merge['qty']

df_merge
# Out:
#    p_id  product  price  sale_id  c_id  qty store  total
# 0     2      RAM     90        4     4    2   DEF    180
# 1     2      RAM     90        7     2    3   ABC    270
# 2     2      RAM     90        8     3    2   DEF    180
# 3     3  Monitor     75        1     2    2   ABC    150
# 4     3  Monitor     75        3     1    3   ABC    225
# 5     3  Monitor     75        5     2    3   ABC    225
# 6     3  Monitor     75        6     3    2   DEF    150
# 7     3  Monitor     75        9     2    2   ABC    150
# 8     4      CPU     55        2     2    1   DEF     55

# %%
df_merge.groupby(['product'], as_index=False).agg({'total': 'sum'})
# Out:
#    product  total
# 0      CPU     55
# 1  Monitor    900
# 2      RAM    630

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q21: List of quantity sold against each product and against each store and sort by store and product.

# %%
# sorted by store
df_merge.groupby(['store','product'], as_index=False).agg({'qty':'sum'})
# Out:
#   store  product  qty
# 0   ABC  Monitor   10
# 1   ABC      RAM    3
# 2   DEF      CPU    1
# 3   DEF  Monitor    2
# 4   DEF      RAM    4

# %%
# sorted by product
df_merge.groupby(['product','store'], as_index=False).agg({'qty':'sum'})
# Out:
#    product store  qty
# 0      CPU   DEF    1
# 1  Monitor   ABC   10
# 2  Monitor   DEF    2
# 3      RAM   ABC    3
# 4      RAM   DEF    4

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q22: List of quantity sold against each Store with total turnover of the store.

# %%
df_merge
# Out:
#    p_id  product  price  sale_id  c_id  qty store  total
# 0     2      RAM     90        4     4    2   DEF    180
# 1     2      RAM     90        7     2    3   ABC    270
# 2     2      RAM     90        8     3    2   DEF    180
# 3     3  Monitor     75        1     2    2   ABC    150
# 4     3  Monitor     75        3     1    3   ABC    225
# 5     3  Monitor     75        5     2    3   ABC    225
# 6     3  Monitor     75        6     3    2   DEF    150
# 7     3  Monitor     75        9     2    2   ABC    150
# 8     4      CPU     55        2     2    1   DEF     55

# %%
df_merge.groupby(['store'], as_index=False).agg({'qty':'sum','total':'sum'})
# Out:
#   store  qty  total
# 0   ABC   13   1020
# 1   DEF    7    565

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q23: List the products which are not sold.

# %%
sold_qty = df_merge.groupby(['product'], as_index=False).agg({'qty':'sum'})
sold_qty
# Out:
#    product  qty
# 0      CPU    1
# 1  Monitor   12
# 2      RAM    7

# %%
unsold = pd.merge(sold_qty,df_p, how='outer')
unsold
# Out:
#         product   qty  p_id  price
# 0           CPU   1.0     4     55
# 1       Monitor  12.0     3     75
# 2           RAM   7.0     2     90
# 3     Hard Disk   NaN     1     80
# 4      Keyboard   NaN     5     20
# 5         Mouse   NaN     6     10
# 6   Motherboard   NaN     7     50
# 7  Power supply   NaN     8     20

# %%
unsold[unsold['qty'].isnull()]
# Out:
#         product  qty  p_id  price
# 3     Hard Disk  NaN     1     80
# 4      Keyboard  NaN     5     20
# 5         Mouse  NaN     6     10
# 6   Motherboard  NaN     7     50
# 7  Power supply  NaN     8     20

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q24: List of customers who have not purchased any product.

# %%
df_c
# Out:
#    c_id Customer
# 0     1     Rabi
# 1     2     Raju
# 2     3     Alex
# 3     4     Rani
# 4     5     King
# 5     7     Ronn
# 6     8      Jem
# 7     9      Tom

# %%
df_s
# Out:
#    sale_id  c_id  p_id  product  qty store
# 0        1     2     3  Monitor    2   ABC
# 1        2     2     4      CPU    1   DEF
# 2        3     1     3  Monitor    3   ABC
# 3        4     4     2      RAM    2   DEF
# 4        5     2     3  Monitor    3   ABC
# 5        6     3     3  Monitor    2   DEF
# 6        7     2     2      RAM    3   ABC
# 7        8     3     2      RAM    2   DEF
# 8        9     2     3  Monitor    2   ABC

# %%
unpurchased = pd.merge(df_c,df_s, how='outer')
unpurchased
# Out:
#     c_id Customer  sale_id  p_id  product  qty store
# 0      1     Rabi      3.0   3.0  Monitor  3.0   ABC
# 1      2     Raju      1.0   3.0  Monitor  2.0   ABC
# 2      2     Raju      2.0   4.0      CPU  1.0   DEF
# 3      2     Raju      5.0   3.0  Monitor  3.0   ABC
# 4      2     Raju      7.0   2.0      RAM  3.0   ABC
# 5      2     Raju      9.0   3.0  Monitor  2.0   ABC
# 6      3     Alex      6.0   3.0  Monitor  2.0   DEF
# 7      3     Alex      8.0   2.0      RAM  2.0   DEF
# 8      4     Rani      4.0   2.0      RAM  2.0   DEF
# 9      5     King      NaN   NaN      NaN  NaN   NaN
# 10     7     Ronn      NaN   NaN      NaN  NaN   NaN
# 11     8      Jem      NaN   NaN      NaN  NaN   NaN
# 12     9      Tom      NaN   NaN      NaN  NaN   NaN

# %%
customer_nopurchase = unpurchased[unpurchased['qty'].isnull()]

# %%
print(customer_nopurchase['Customer'])
# Out:
# 9     King
# 10    Ronn
# 11     Jem
# 12     Tom
# Name: Customer, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q25: Assign a 'birthday_this_year' column to the customer table where each customer has a birthday associated with them in the yyyy-mm-dd format.
# #### Let c_id = 1 have birthday '2020-01-01', then let the next customer c_id = 2 have a birthday 1 days later than that the birthday of c_id = 1.
# #### Continue in this way such that customer c_id = 3 has their birthday 2 days later than the birthday of c_id = 2 and so on.
# #### Finally, customer c_id = 9 will have their birthday 8 days later than the birthday of c_id = 8.

# %%
df_c
# Out:
#    c_id Customer
# 0     1     Rabi
# 1     2     Raju
# 2     3     Alex
# 3     4     Rani
# 4     5     King
# 5     7     Ronn
# 6     8      Jem
# 7     9      Tom

# %%
df_c['birthday_this_year'] = pd.to_datetime('1/1/2020')

df_c
# Out:
#    c_id Customer birthday_this_year
# 0     1     Rabi         2020-01-01
# 1     2     Raju         2020-01-01
# 2     3     Alex         2020-01-01
# 3     4     Rani         2020-01-01
# 4     5     King         2020-01-01
# 5     7     Ronn         2020-01-01
# 6     8      Jem         2020-01-01
# 7     9      Tom         2020-01-01

# %%
for i in range(0,8):
    if i == 0:
        df_c.loc[i,'birthday_this_year'] = df_c.loc[i,'birthday_this_year']
    else:
        df_c.loc[i,'birthday_this_year'] = df_c.loc[(i-1),'birthday_this_year'] + (pd.to_timedelta(df_c.loc[(i-1),'c_id'], unit='d'))
    
df_c
# Out:
#    c_id Customer birthday_this_year
# 0     1     Rabi         2020-01-01
# 1     2     Raju         2020-01-02
# 2     3     Alex         2020-01-04
# 3     4     Rani         2020-01-07
# 4     5     King         2020-01-11
# 5     7     Ronn         2020-01-16
# 6     8      Jem         2020-01-23
# 7     9      Tom         2020-01-31

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q26:
# #### 1. Make a dataframe for the new customer
# #### pd.DataFrame({'c_id': [10, 11, 12, 13], 'Customer': ['James', 'Bill', 'Susie', 'Emma'], 'birthday_this_year': ['2020-07-28', '2020-04-05', '2020-11-25', '2020-06-14']})
# #### 2. and union this dataframe with the current customer dataframe. Ensure all column types are the same.
# #### 3. Sort customers by c_id in ascending order and
# #### 4. reset the index.

# %%
df_c_new = pd.DataFrame({'c_id': [10, 11, 12, 13], 'Customer': 
                         ['James', 'Bill', 'Susie', 'Emma'], 'birthday_this_year': 
                         ['2020-07-28', '2020-04-05', '2020-11-25', '2020-06-14']})

df_c_new
# Out:
#    c_id Customer birthday_this_year
# 0    10    James         2020-07-28
# 1    11     Bill         2020-04-05
# 2    12    Susie         2020-11-25
# 3    13     Emma         2020-06-14

# %%
df_c.dtypes
# Out:
# c_id                           int64
# Customer                      object
# birthday_this_year    datetime64[ns]
# dtype: object

# %%
df_c_new.dtypes
# Out:
# c_id                   int64
# Customer              object
# birthday_this_year    object
# dtype: object

# %%
df_c_new.birthday_this_year = df_c_new.birthday_this_year.astype('datetime64')

# %%
df_c_new.dtypes
# Out:
# c_id                           int64
# Customer                      object
# birthday_this_year    datetime64[ns]
# dtype: object

# %%
df_c_total = pd.concat([df_c,df_c_new], ignore_index=True)
df_c_total
# Out:
#     c_id Customer birthday_this_year
# 0      1     Rabi         2020-01-01
# 1      2     Raju         2020-01-02
# 2      3     Alex         2020-01-04
# 3      4     Rani         2020-01-07
# 4      5     King         2020-01-11
# 5      7     Ronn         2020-01-16
# 6      8      Jem         2020-01-23
# 7      9      Tom         2020-01-31
# 8     10    James         2020-07-28
# 9     11     Bill         2020-04-05
# 10    12    Susie         2020-11-25
# 11    13     Emma         2020-06-14

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q27: Add an indicator column in the sales table called 'qty_multiple_2' where 1 indicates if the qty is a multiple of 2 and 0 otherwise.

# %%
df_s
# Out:
#    sale_id  c_id  p_id  product  qty store
# 0        1     2     3  Monitor    2   ABC
# 1        2     2     4      CPU    1   DEF
# 2        3     1     3  Monitor    3   ABC
# 3        4     4     2      RAM    2   DEF
# 4        5     2     3  Monitor    3   ABC
# 5        6     3     3  Monitor    2   DEF
# 6        7     2     2      RAM    3   ABC
# 7        8     3     2      RAM    2   DEF
# 8        9     2     3  Monitor    2   ABC

# %%
df_s['qty_multiple_2'] = ""
df_s
# Out:
#    sale_id  c_id  p_id  product  qty store qty_multiple_2
# 0        1     2     3  Monitor    2   ABC
# 1        2     2     4      CPU    1   DEF
# 2        3     1     3  Monitor    3   ABC
# 3        4     4     2      RAM    2   DEF
# 4        5     2     3  Monitor    3   ABC
# 5        6     3     3  Monitor    2   DEF
# 6        7     2     2      RAM    3   ABC
# 7        8     3     2      RAM    2   DEF
# 8        9     2     3  Monitor    2   ABC

# %%
df_s.columns
# Out:
# Index(['sale_id', 'c_id', 'p_id', 'product', 'qty', 'store', 'qty_multiple_2'], dtype='object')

# %%
for i in range(0,len(df_s)):
    if df_s.loc[i,'qty'] % 2== 0:
        df_s.loc[i,'qty_multiple_2'] = 1
    else:
        df_s.loc[i,'qty_multiple_2'] = 0

# %%
df_s
# Out:
#    sale_id  c_id  p_id  product  qty store qty_multiple_2
# 0        1     2     3  Monitor    2   ABC              1
# 1        2     2     4      CPU    1   DEF              0
# 2        3     1     3  Monitor    3   ABC              0
# 3        4     4     2      RAM    2   DEF              1
# 4        5     2     3  Monitor    3   ABC              0
# 5        6     3     3  Monitor    2   DEF              1
# 6        7     2     2      RAM    3   ABC              0
# 7        8     3     2      RAM    2   DEF              1
# 8        9     2     3  Monitor    2   ABC              1

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q28: Create a column called Age in the new customers table where each customer has ages [24, 29, 42, 35, 32, 28, 19, 38, 27, 29, 34, 25].

# %%
df_c_total
# Out:
#     c_id Customer birthday_this_year
# 0      1     Rabi         2020-01-01
# 1      2     Raju         2020-01-02
# 2      3     Alex         2020-01-04
# 3      4     Rani         2020-01-07
# 4      5     King         2020-01-11
# 5      7     Ronn         2020-01-16
# 6      8      Jem         2020-01-23
# 7      9      Tom         2020-01-31
# 8     10    James         2020-07-28
# 9     11     Bill         2020-04-05
# 10    12    Susie         2020-11-25
# 11    13     Emma         2020-06-14

# %%
df_c_total['ages'] = [24, 29, 42, 35, 32, 28, 19, 38, 27, 29, 34, 25]
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages
# 0      1     Rabi         2020-01-01    24
# 1      2     Raju         2020-01-02    29
# 2      3     Alex         2020-01-04    42
# 3      4     Rani         2020-01-07    35
# 4      5     King         2020-01-11    32
# 5      7     Ronn         2020-01-16    28
# 6      8      Jem         2020-01-23    19
# 7      9      Tom         2020-01-31    38
# 8     10    James         2020-07-28    27
# 9     11     Bill         2020-04-05    29
# 10    12    Susie         2020-11-25    34
# 11    13     Emma         2020-06-14    25

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q29: Compute the date of birth for each customer.

# %%
from datetime import datetime

# %%
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages
# 0      1     Rabi         2020-01-01    24
# 1      2     Raju         2020-01-02    29
# 2      3     Alex         2020-01-04    42
# 3      4     Rani         2020-01-07    35
# 4      5     King         2020-01-11    32
# 5      7     Ronn         2020-01-16    28
# 6      8      Jem         2020-01-23    19
# 7      9      Tom         2020-01-31    38
# 8     10    James         2020-07-28    27
# 9     11     Bill         2020-04-05    29
# 10    12    Susie         2020-11-25    34
# 11    13     Emma         2020-06-14    25

# %%
df_c_total.dtypes
# Out:
# c_id                           int64
# Customer                      object
# birthday_this_year    datetime64[ns]
# ages                           int64
# dtype: object

# %%
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
import datetime

# %%
df_c_total['this_year'] = pd.DatetimeIndex(df_c_total['birthday_this_year']).year
df_c_total['this_month'] = pd.DatetimeIndex(df_c_total['birthday_this_year']).month
df_c_total['this_day'] = pd.DatetimeIndex(df_c_total['birthday_this_year']).day

df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
df_c_total['dob_year'] = df_c_total['this_year'] - df_c_total['ages']

df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
df_c_total["dob"] = df_c_total["this_day"].astype(str) + "/" + df_c_total["this_month"].astype(str) + "/" + df_c_total["dob_year"].astype(str)

df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
df_c_total.dob = df_c_total.dob.astype('datetime64')

# %%
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q30: In the most recent customer table, assign a column which tells us which astrology star sign each customer is.

# %%
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
df_c_total['star'] = ""
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
for i in range (12):
    if df_c_total.loc[i,'this_month'] == 1 and df_c_total.loc[i,'this_day'] < 20:
        df_c_total.loc[i,'star'] = 'capricorn'
    elif df_c_total.loc[i,'this_month'] == 1 and df_c_total.loc[i,'this_day'] > 19:
        df_c_total.loc[i,'star'] = 'aquarius'
    elif df_c_total.loc[i,'this_month'] == 2 and df_c_total.loc[i,'this_day'] < 19:
        df_c_total.loc[i,'star'] = 'aquarius'
    elif df_c_total.loc[i,'this_month'] == 2 and df_c_total.loc[i,'this_day'] > 18:
        df_c_total.loc[i,'star'] = 'pices'
    elif df_c_total.loc[i,'this_month'] == 3 and df_c_total.loc[i,'this_day'] < 21:
        df_c_total.loc[i,'star'] = 'pices'
    elif df_c_total.loc[i,'this_month'] == 3 and df_c_total.loc[i,'this_day'] > 20:
        df_c_total.loc[i,'star'] = 'aries'
    elif df_c_total.loc[i,'this_month'] == 4 and df_c_total.loc[i,'this_day'] < 20:
        df_c_total.loc[i,'star'] = 'aries'
    elif df_c_total.loc[i,'this_month'] == 4 and df_c_total.loc[i,'this_day'] < 19:
        df_c_total.loc[i,'star'] = 'taurus'
    elif df_c_total.loc[i,'this_month'] == 5 and df_c_total.loc[i,'this_day'] < 21:
        df_c_total.loc[i,'star'] = 'taurus'
    elif df_c_total.loc[i,'this_month'] == 5 and df_c_total.loc[i,'this_day'] > 20:
        df_c_total.loc[i,'star'] = 'gemini'
    elif df_c_total.loc[i,'this_month'] == 6 and df_c_total.loc[i,'this_day'] < 21:
        df_c_total.loc[i,'star'] = 'gemini'
    elif df_c_total.loc[i,'this_month'] == 6 and df_c_total.loc[i,'this_day'] > 20:
        df_c_total.loc[i,'star'] = 'cancer'
    elif df_c_total.loc[i,'this_month'] == 7 and df_c_total.loc[i,'this_day'] < 23:
        df_c_total.loc[i,'star'] = 'cancer'
    elif df_c_total.loc[i,'this_month'] == 7 and df_c_total.loc[i,'this_day'] > 22:
        df_c_total.loc[i,'star'] = 'leo'
    elif df_c_total.loc[i,'this_month'] == 8 and df_c_total.loc[i,'this_day'] < 23:
        df_c_total.loc[i,'star'] = 'leo'
    elif df_c_total.loc[i,'this_month'] == 8 and df_c_total.loc[i,'this_day'] > 22:
        df_c_total.loc[i,'star'] = 'virgo'
    elif df_c_total.loc[i,'this_month'] == 9 and df_c_total.loc[i,'this_day'] < 23:
        df_c_total.loc[i,'star'] = 'virgo'
    elif df_c_total.loc[i,'this_month'] == 9 and df_c_total.loc[i,'this_day'] > 22:
        df_c_total.loc[i,'star'] = 'libra'
    elif df_c_total.loc[i,'this_month'] == 10 and df_c_total.loc[i,'this_day'] < 23:
        df_c_total.loc[i,'star'] = 'libra'
    elif df_c_total.loc[i,'this_month'] == 10 and df_c_total.loc[i,'this_day'] > 22:
        df_c_total.loc[i,'star'] = 'scorpio'
    elif df_c_total.loc[i,'this_month'] == 11 and df_c_total.loc[i,'this_day'] < 22:
        df_c_total.loc[i,'star'] = 'scorpio'
    elif df_c_total.loc[i,'this_month'] == 11 and df_c_total.loc[i,'this_day'] > 21:
        df_c_total.loc[i,'star'] = 'sagittarius'
    elif df_c_total.loc[i,'this_month'] == 12 and df_c_total.loc[i,'this_day'] < 22:
        df_c_total.loc[i,'star'] = 'sagittarius'
    elif df_c_total.loc[i,'this_month'] == 12 and df_c_total.loc[i,'this_day'] > 21:
        df_c_total.loc[i,'star'] = 'capricorn'
        
df_c_total
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %%
df_c_total.drop(['zodiac_sign'], axis=1)
# Out:
#     c_id Customer birthday_this_year  ages  this_year  this_month  this_day  \
# 0      1     Rabi         2020-01-01    24       2020           1         1
# 1      2     Raju         2020-01-02    29       2020           1         2
# 2      3     Alex         2020-01-04    42       2020           1         4
# 3      4     Rani         2020-01-07    35       2020           1         7
# 4      5     King         2020-01-11    32       2020           1        11
# 5      7     Ronn         2020-01-16    28       2020           1        16
# 6      8      Jem         2020-01-23    19       2020           1        23
# 7      9      Tom         2020-01-31    38       2020           1        31
# 8     10    James         2020-07-28    27       2020           7        28
# 9     11     Bill         2020-04-05    29       2020           4         5
# 10    12    Susie         2020-11-25    34       2020          11        25
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Q31: Consider the rectangles dataset, read it in, compute the area of each rectangle and save the file to CSV called 'rectangles_new'.

# %%
df_r
# Out:
#    height  width
# 0    40.0     10
# 1    20.0      9
# 2     3.4      4

# %%
df_r['area'] = df_r['height']*df_r['width']
df_r
# Out:
#    height  width   area
# 0    40.0     10  400.0
# 1    20.0      9  180.0
# 2     3.4      4   13.6

# %%
df_r.to_csv('area.csv')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## THE END
